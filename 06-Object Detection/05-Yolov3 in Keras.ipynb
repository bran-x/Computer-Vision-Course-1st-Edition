# %% [markdown]
# # Yolo v3 en Tensorflow y Keras

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization,  LeakyReLU, ZeroPadding2D, UpSampling2D
from tensorflow.keras.layers import Add, Concatenate
from tensorflow.keras import models
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ## 1. Darknet 53

# %%
def DarknetConv2D(x,*args, **kwargs):
  darknet_kwargs = {'kernel_regularizer': l2(5e-4)}
  darknet_kwargs['padding'] = 'valid' if kwargs.get('strides')==(2,2) else 'same'
  darknet_kwargs.update(kwargs)
  return Conv2D(*args, **darknet_kwargs)(x)

# %%
def DarknetConv2D_BN_LR(x,*args, **kwargs):
  no_bias_kwargs = {'use_bias':False}
  no_bias_kwargs.update(kwargs)
  idx = no_bias_kwargs.pop('idx')
  x = DarknetConv2D(x,*args, **no_bias_kwargs, name='conv_'+str(idx))
  x = BatchNormalization(name='bnorm_'+str(idx))(x)
  x = LeakyReLU(alpha=0.1,name='leaky_'+str(idx))(x)
  return x

# %%
def DarknetResidual(x, filters, blocks, idx):
  x = ZeroPadding2D(((1,0),(1,0)))(x)
  x = DarknetConv2D_BN_LR(x, filters, 3, strides=(2,2), idx=idx)
  for i in range(blocks):
    idx += 1
    y = DarknetConv2D_BN_LR(x,filters//2, 1, idx=idx)
    idx += 1
    y = DarknetConv2D_BN_LR(y,filters, 3, idx=idx)
    idx += 1
    x = Add()([x,y])
  return x, idx+1

# %%
def DarknetBody(x):
  x = DarknetConv2D_BN_LR(x,32, 3, idx=0) # Conv 0
  x, idx = DarknetResidual(x,64,1, idx=1) # Conv 1-4
  x, idx = DarknetResidual(x,128,2, idx=idx)
  x, idx = DarknetResidual(x,256,8, idx=idx)
  skip_36 = x
  x, idx = DarknetResidual(x,512,8, idx=idx)
  skip_61 = x
  x, idx = DarknetResidual(x,1024,4, idx=idx) # Linea 547 yolov3.cfg
  return x, idx, [skip_36, skip_61]

# %%
def LastLayers(x, filters, out_filters, idxs):
  x = DarknetConv2D_BN_LR(x,filters, 1, idx = idxs[0])
  x = DarknetConv2D_BN_LR(x,2*filters, 3, idx = idxs[1])
  x = DarknetConv2D_BN_LR(x,filters, 1, idx = idxs[2])
  x = DarknetConv2D_BN_LR(x,2*filters, 3, idx = idxs[3])
  x = DarknetConv2D_BN_LR(x,filters, 1, idx = idxs[4])

  y = DarknetConv2D_BN_LR(x,2*filters, 3, idx = idxs[5])
  y = DarknetConv2D(y,out_filters, 1, name='conv_'+str(idxs[6]))
  return x,y

# %%
def Yolov3Body(inputs, n_anchors, n_class):
  x, idx, skips = DarknetBody(inputs)
  # skips: [skip_36, skip_61]
  darknet = models.Model(inputs, x)
  idxs = list(range(idx,idx+7))
  x, yolo_82 = LastLayers(darknet.output, 512, n_anchors*(n_class+5), idxs)
  x = DarknetConv2D_BN_LR(x,256, 1, idx=84)
  x = UpSampling2D(2)(x)
  x = Concatenate()([x,skips[1]])

  idxs = list(range(87,94))
  x, yolo_94 = LastLayers(x, 256, n_anchors*(n_class+5), idxs)
  x = DarknetConv2D_BN_LR(x,128, 1, idx=96)
  x = UpSampling2D(2)(x)
  x = Concatenate()([x,skips[0]])

  idxs = list(range(99,106))
  x, yolo_106 = LastLayers(x, 128, n_anchors*(n_class+5), idxs)
  
  return models.Model(inputs, [yolo_82,yolo_94,yolo_106])

# %% [markdown]
# ## 2. Yolov3

# %%
inputs = Input(shape=(416,416,3))
model = Yolov3Body(inputs, 3, 80)

# %%
len(model.layers)
# Out:
# 252

# %%
model.summary()
# Out:
# Model: "model_28"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_23 (InputLayer)          [(None, 416, 416, 3  0           []
#                                 )]
#
#  conv_0 (Conv2D)                (None, 416, 416, 32  864         ['input_23[0][0]']
#                                 )
#
#  bnorm_0 (BatchNormalization)   (None, 416, 416, 32  128         ['conv_0[0][0]']
#                                 )
#
#  leaky_0 (LeakyReLU)            (None, 416, 416, 32  0           ['bnorm_0[0][0]']
#                                 )
#
#  zero_padding2d_90 (ZeroPadding  (None, 417, 417, 32  0          ['leaky_0[0][0]']
#  2D)                            )
#
#  conv_1 (Conv2D)                (None, 208, 208, 64  18432       ['zero_padding2d_90[0][0]']
#                                 )
#
#  bnorm_1 (BatchNormalization)   (None, 208, 208, 64  256         ['conv_1[0][0]']
#                                 )
#
#  leaky_1 (LeakyReLU)            (None, 208, 208, 64  0           ['bnorm_1[0][0]']
#                                 )
#
#  conv_2 (Conv2D)                (None, 208, 208, 32  2048        ['leaky_1[0][0]']
#                                 )
#
#  bnorm_2 (BatchNormalization)   (None, 208, 208, 32  128         ['conv_2[0][0]']
#                                 )
#
#  leaky_2 (LeakyReLU)            (None, 208, 208, 32  0           ['bnorm_2[0][0]']
#                                 )
#
#  conv_3 (Conv2D)                (None, 208, 208, 64  18432       ['leaky_2[0][0]']
#                                 )
#
#  bnorm_3 (BatchNormalization)   (None, 208, 208, 64  256         ['conv_3[0][0]']
#                                 )
#
#  leaky_3 (LeakyReLU)            (None, 208, 208, 64  0           ['bnorm_3[0][0]']
#                                 )
#
#  add_414 (Add)                  (None, 208, 208, 64  0           ['leaky_1[0][0]',
#                                 )                                 'leaky_3[0][0]']
#
#  zero_padding2d_91 (ZeroPadding  (None, 209, 209, 64  0          ['add_414[0][0]']
#  2D)                            )
#
#  conv_5 (Conv2D)                (None, 104, 104, 12  73728       ['zero_padding2d_91[0][0]']
#                                 8)
#
#  bnorm_5 (BatchNormalization)   (None, 104, 104, 12  512         ['conv_5[0][0]']
#                                 8)
#
#  leaky_5 (LeakyReLU)            (None, 104, 104, 12  0           ['bnorm_5[0][0]']
#                                 8)
#
#  conv_6 (Conv2D)                (None, 104, 104, 64  8192        ['leaky_5[0][0]']
#                                 )
#
#  bnorm_6 (BatchNormalization)   (None, 104, 104, 64  256         ['conv_6[0][0]']
#                                 )
#
#  leaky_6 (LeakyReLU)            (None, 104, 104, 64  0           ['bnorm_6[0][0]']
#                                 )
#
#  conv_7 (Conv2D)                (None, 104, 104, 12  73728       ['leaky_6[0][0]']
#                                 8)
#
#  bnorm_7 (BatchNormalization)   (None, 104, 104, 12  512         ['conv_7[0][0]']
#                                 8)
#
#  leaky_7 (LeakyReLU)            (None, 104, 104, 12  0           ['bnorm_7[0][0]']
#                                 8)
#
#  add_415 (Add)                  (None, 104, 104, 12  0           ['leaky_5[0][0]',
#                                 8)                                'leaky_7[0][0]']
#
#  conv_9 (Conv2D)                (None, 104, 104, 64  8192        ['add_415[0][0]']
#                                 )
#
#  bnorm_9 (BatchNormalization)   (None, 104, 104, 64  256         ['conv_9[0][0]']
#                                 )
#
#  leaky_9 (LeakyReLU)            (None, 104, 104, 64  0           ['bnorm_9[0][0]']
#                                 )
#
#  conv_10 (Conv2D)               (None, 104, 104, 12  73728       ['leaky_9[0][0]']
#                                 8)
#
#  bnorm_10 (BatchNormalization)  (None, 104, 104, 12  512         ['conv_10[0][0]']
#                                 8)
#
#  leaky_10 (LeakyReLU)           (None, 104, 104, 12  0           ['bnorm_10[0][0]']
#                                 8)
#
#  add_416 (Add)                  (None, 104, 104, 12  0           ['add_415[0][0]',
#                                 8)                                'leaky_10[0][0]']
#
#  zero_padding2d_92 (ZeroPadding  (None, 105, 105, 12  0          ['add_416[0][0]']
#  2D)                            8)
#
#  conv_12 (Conv2D)               (None, 52, 52, 256)  294912      ['zero_padding2d_92[0][0]']
#
#  bnorm_12 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_12[0][0]']
#
#  leaky_12 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_12[0][0]']
#
#  conv_13 (Conv2D)               (None, 52, 52, 128)  32768       ['leaky_12[0][0]']
#
#  bnorm_13 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_13[0][0]']
#
#  leaky_13 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_13[0][0]']
#
#  conv_14 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_13[0][0]']
#
#  bnorm_14 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_14[0][0]']
#
#  leaky_14 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_14[0][0]']
#
#  add_417 (Add)                  (None, 52, 52, 256)  0           ['leaky_12[0][0]',
#                                                                   'leaky_14[0][0]']
#
#  conv_16 (Conv2D)               (None, 52, 52, 128)  32768       ['add_417[0][0]']
#
#  bnorm_16 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_16[0][0]']
#
#  leaky_16 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_16[0][0]']
#
#  conv_17 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_16[0][0]']
#
#  bnorm_17 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_17[0][0]']
#
#  leaky_17 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_17[0][0]']
#
#  add_418 (Add)                  (None, 52, 52, 256)  0           ['add_417[0][0]',
#                                                                   'leaky_17[0][0]']
#
#  conv_19 (Conv2D)               (None, 52, 52, 128)  32768       ['add_418[0][0]']
#
#  bnorm_19 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_19[0][0]']
#
#  leaky_19 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_19[0][0]']
#
#  conv_20 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_19[0][0]']
#
#  bnorm_20 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_20[0][0]']
#
#  leaky_20 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_20[0][0]']
#
#  add_419 (Add)                  (None, 52, 52, 256)  0           ['add_418[0][0]',
#                                                                   'leaky_20[0][0]']
#
#  conv_22 (Conv2D)               (None, 52, 52, 128)  32768       ['add_419[0][0]']
#
#  bnorm_22 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_22[0][0]']
#
#  leaky_22 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_22[0][0]']
#
#  conv_23 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_22[0][0]']
#
#  bnorm_23 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_23[0][0]']
#
#  leaky_23 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_23[0][0]']
#
#  add_420 (Add)                  (None, 52, 52, 256)  0           ['add_419[0][0]',
#                                                                   'leaky_23[0][0]']
#
#  conv_25 (Conv2D)               (None, 52, 52, 128)  32768       ['add_420[0][0]']
#
#  bnorm_25 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_25[0][0]']
#
#  leaky_25 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_25[0][0]']
#
#  conv_26 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_25[0][0]']
#
#  bnorm_26 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_26[0][0]']
#
#  leaky_26 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_26[0][0]']
#
#  add_421 (Add)                  (None, 52, 52, 256)  0           ['add_420[0][0]',
#                                                                   'leaky_26[0][0]']
#
#  conv_28 (Conv2D)               (None, 52, 52, 128)  32768       ['add_421[0][0]']
#
#  bnorm_28 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_28[0][0]']
#
#  leaky_28 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_28[0][0]']
#
#  conv_29 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_28[0][0]']
#
#  bnorm_29 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_29[0][0]']
#
#  leaky_29 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_29[0][0]']
#
#  add_422 (Add)                  (None, 52, 52, 256)  0           ['add_421[0][0]',
#                                                                   'leaky_29[0][0]']
#
#  conv_31 (Conv2D)               (None, 52, 52, 128)  32768       ['add_422[0][0]']
#
#  bnorm_31 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_31[0][0]']
#
#  leaky_31 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_31[0][0]']
#
#  conv_32 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_31[0][0]']
#
#  bnorm_32 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_32[0][0]']
#
#  leaky_32 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_32[0][0]']
#
#  add_423 (Add)                  (None, 52, 52, 256)  0           ['add_422[0][0]',
#                                                                   'leaky_32[0][0]']
#
#  conv_34 (Conv2D)               (None, 52, 52, 128)  32768       ['add_423[0][0]']
#
#  bnorm_34 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_34[0][0]']
#
#  leaky_34 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_34[0][0]']
#
#  conv_35 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_34[0][0]']
#
#  bnorm_35 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_35[0][0]']
#
#  leaky_35 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_35[0][0]']
#
#  add_424 (Add)                  (None, 52, 52, 256)  0           ['add_423[0][0]',
#                                                                   'leaky_35[0][0]']
#
#  zero_padding2d_93 (ZeroPadding  (None, 53, 53, 256)  0          ['add_424[0][0]']
#  2D)
#
#  conv_37 (Conv2D)               (None, 26, 26, 512)  1179648     ['zero_padding2d_93[0][0]']
#
#  bnorm_37 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_37[0][0]']
#
#  leaky_37 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_37[0][0]']
#
#  conv_38 (Conv2D)               (None, 26, 26, 256)  131072      ['leaky_37[0][0]']
#
#  bnorm_38 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_38[0][0]']
#
#  leaky_38 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_38[0][0]']
#
#  conv_39 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_38[0][0]']
#
#  bnorm_39 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_39[0][0]']
#
#  leaky_39 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_39[0][0]']
#
#  add_425 (Add)                  (None, 26, 26, 512)  0           ['leaky_37[0][0]',
#                                                                   'leaky_39[0][0]']
#
#  conv_41 (Conv2D)               (None, 26, 26, 256)  131072      ['add_425[0][0]']
#
#  bnorm_41 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_41[0][0]']
#
#  leaky_41 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_41[0][0]']
#
#  conv_42 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_41[0][0]']
#
#  bnorm_42 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_42[0][0]']
#
#  leaky_42 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_42[0][0]']
#
#  add_426 (Add)                  (None, 26, 26, 512)  0           ['add_425[0][0]',
#                                                                   'leaky_42[0][0]']
#
#  conv_44 (Conv2D)               (None, 26, 26, 256)  131072      ['add_426[0][0]']
#
#  bnorm_44 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_44[0][0]']
#
#  leaky_44 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_44[0][0]']
#
#  conv_45 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_44[0][0]']
#
#  bnorm_45 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_45[0][0]']
#
#  leaky_45 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_45[0][0]']
#
#  add_427 (Add)                  (None, 26, 26, 512)  0           ['add_426[0][0]',
#                                                                   'leaky_45[0][0]']
#
#  conv_47 (Conv2D)               (None, 26, 26, 256)  131072      ['add_427[0][0]']
#
#  bnorm_47 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_47[0][0]']
#
#  leaky_47 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_47[0][0]']
#
#  conv_48 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_47[0][0]']
#
#  bnorm_48 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_48[0][0]']
#
#  leaky_48 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_48[0][0]']
#
#  add_428 (Add)                  (None, 26, 26, 512)  0           ['add_427[0][0]',
#                                                                   'leaky_48[0][0]']
#
#  conv_50 (Conv2D)               (None, 26, 26, 256)  131072      ['add_428[0][0]']
#
#  bnorm_50 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_50[0][0]']
#
#  leaky_50 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_50[0][0]']
#
#  conv_51 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_50[0][0]']
#
#  bnorm_51 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_51[0][0]']
#
#  leaky_51 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_51[0][0]']
#
#  add_429 (Add)                  (None, 26, 26, 512)  0           ['add_428[0][0]',
#                                                                   'leaky_51[0][0]']
#
#  conv_53 (Conv2D)               (None, 26, 26, 256)  131072      ['add_429[0][0]']
#
#  bnorm_53 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_53[0][0]']
#
#  leaky_53 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_53[0][0]']
#
#  conv_54 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_53[0][0]']
#
#  bnorm_54 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_54[0][0]']
#
#  leaky_54 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_54[0][0]']
#
#  add_430 (Add)                  (None, 26, 26, 512)  0           ['add_429[0][0]',
#                                                                   'leaky_54[0][0]']
#
#  conv_56 (Conv2D)               (None, 26, 26, 256)  131072      ['add_430[0][0]']
#
#  bnorm_56 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_56[0][0]']
#
#  leaky_56 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_56[0][0]']
#
#  conv_57 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_56[0][0]']
#
#  bnorm_57 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_57[0][0]']
#
#  leaky_57 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_57[0][0]']
#
#  add_431 (Add)                  (None, 26, 26, 512)  0           ['add_430[0][0]',
#                                                                   'leaky_57[0][0]']
#
#  conv_59 (Conv2D)               (None, 26, 26, 256)  131072      ['add_431[0][0]']
#
#  bnorm_59 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_59[0][0]']
#
#  leaky_59 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_59[0][0]']
#
#  conv_60 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_59[0][0]']
#
#  bnorm_60 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_60[0][0]']
#
#  leaky_60 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_60[0][0]']
#
#  add_432 (Add)                  (None, 26, 26, 512)  0           ['add_431[0][0]',
#                                                                   'leaky_60[0][0]']
#
#  zero_padding2d_94 (ZeroPadding  (None, 27, 27, 512)  0          ['add_432[0][0]']
#  2D)
#
#  conv_62 (Conv2D)               (None, 13, 13, 1024  4718592     ['zero_padding2d_94[0][0]']
#                                 )
#
#  bnorm_62 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_62[0][0]']
#                                 )
#
#  leaky_62 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_62[0][0]']
#                                 )
#
#  conv_63 (Conv2D)               (None, 13, 13, 512)  524288      ['leaky_62[0][0]']
#
#  bnorm_63 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_63[0][0]']
#
#  leaky_63 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_63[0][0]']
#
#  conv_64 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_63[0][0]']
#                                 )
#
#  bnorm_64 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_64[0][0]']
#                                 )
#
#  leaky_64 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_64[0][0]']
#                                 )
#
#  add_433 (Add)                  (None, 13, 13, 1024  0           ['leaky_62[0][0]',
#                                 )                                 'leaky_64[0][0]']
#
#  conv_66 (Conv2D)               (None, 13, 13, 512)  524288      ['add_433[0][0]']
#
#  bnorm_66 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_66[0][0]']
#
#  leaky_66 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_66[0][0]']
#
#  conv_67 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_66[0][0]']
#                                 )
#
#  bnorm_67 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_67[0][0]']
#                                 )
#
#  leaky_67 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_67[0][0]']
#                                 )
#
#  add_434 (Add)                  (None, 13, 13, 1024  0           ['add_433[0][0]',
#                                 )                                 'leaky_67[0][0]']
#
#  conv_69 (Conv2D)               (None, 13, 13, 512)  524288      ['add_434[0][0]']
#
#  bnorm_69 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_69[0][0]']
#
#  leaky_69 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_69[0][0]']
#
#  conv_70 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_69[0][0]']
#                                 )
#
#  bnorm_70 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_70[0][0]']
#                                 )
#
#  leaky_70 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_70[0][0]']
#                                 )
#
#  add_435 (Add)                  (None, 13, 13, 1024  0           ['add_434[0][0]',
#                                 )                                 'leaky_70[0][0]']
#
#  conv_72 (Conv2D)               (None, 13, 13, 512)  524288      ['add_435[0][0]']
#
#  bnorm_72 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_72[0][0]']
#
#  leaky_72 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_72[0][0]']
#
#  conv_73 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_72[0][0]']
#                                 )
#
#  bnorm_73 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_73[0][0]']
#                                 )
#
#  leaky_73 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_73[0][0]']
#                                 )
#
#  add_436 (Add)                  (None, 13, 13, 1024  0           ['add_435[0][0]',
#                                 )                                 'leaky_73[0][0]']
#
#  conv_75 (Conv2D)               (None, 13, 13, 512)  524288      ['add_436[0][0]']
#
#  bnorm_75 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_75[0][0]']
#
#  leaky_75 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_75[0][0]']
#
#  conv_76 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_75[0][0]']
#                                 )
#
#  bnorm_76 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_76[0][0]']
#                                 )
#
#  leaky_76 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_76[0][0]']
#                                 )
#
#  conv_77 (Conv2D)               (None, 13, 13, 512)  524288      ['leaky_76[0][0]']
#
#  bnorm_77 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_77[0][0]']
#
#  leaky_77 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_77[0][0]']
#
#  conv_78 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_77[0][0]']
#                                 )
#
#  bnorm_78 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_78[0][0]']
#                                 )
#
#  leaky_78 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_78[0][0]']
#                                 )
#
#  conv_79 (Conv2D)               (None, 13, 13, 512)  524288      ['leaky_78[0][0]']
#
#  bnorm_79 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_79[0][0]']
#
#  leaky_79 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_79[0][0]']
#
#  conv_84 (Conv2D)               (None, 13, 13, 256)  131072      ['leaky_79[0][0]']
#
#  bnorm_84 (BatchNormalization)  (None, 13, 13, 256)  1024        ['conv_84[0][0]']
#
#  leaky_84 (LeakyReLU)           (None, 13, 13, 256)  0           ['bnorm_84[0][0]']
#
#  up_sampling2d_26 (UpSampling2D  (None, 26, 26, 256)  0          ['leaky_84[0][0]']
#  )
#
#  concatenate_26 (Concatenate)   (None, 26, 26, 768)  0           ['up_sampling2d_26[0][0]',
#                                                                   'add_432[0][0]']
#
#  conv_87 (Conv2D)               (None, 26, 26, 256)  196608      ['concatenate_26[0][0]']
#
#  bnorm_87 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_87[0][0]']
#
#  leaky_87 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_87[0][0]']
#
#  conv_88 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_87[0][0]']
#
#  bnorm_88 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_88[0][0]']
#
#  leaky_88 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_88[0][0]']
#
#  conv_89 (Conv2D)               (None, 26, 26, 256)  131072      ['leaky_88[0][0]']
#
#  bnorm_89 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_89[0][0]']
#
#  leaky_89 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_89[0][0]']
#
#  conv_90 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_89[0][0]']
#
#  bnorm_90 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_90[0][0]']
#
#  leaky_90 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_90[0][0]']
#
#  conv_91 (Conv2D)               (None, 26, 26, 256)  131072      ['leaky_90[0][0]']
#
#  bnorm_91 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_91[0][0]']
#
#  leaky_91 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_91[0][0]']
#
#  conv_96 (Conv2D)               (None, 26, 26, 256)  65536       ['leaky_91[0][0]']
#
#  bnorm_96 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_96[0][0]']
#
#  leaky_96 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_96[0][0]']
#
#  up_sampling2d_27 (UpSampling2D  (None, 52, 52, 256)  0          ['leaky_96[0][0]']
#  )
#
#  concatenate_27 (Concatenate)   (None, 52, 52, 512)  0           ['up_sampling2d_27[0][0]',
#                                                                   'add_424[0][0]']
#
#  conv_99 (Conv2D)               (None, 52, 52, 128)  65536       ['concatenate_27[0][0]']
#
#  bnorm_99 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_99[0][0]']
#
#  leaky_99 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_99[0][0]']
#
#  conv_100 (Conv2D)              (None, 52, 52, 256)  294912      ['leaky_99[0][0]']
#
#  bnorm_100 (BatchNormalization)  (None, 52, 52, 256)  1024       ['conv_100[0][0]']
#
#  leaky_100 (LeakyReLU)          (None, 52, 52, 256)  0           ['bnorm_100[0][0]']
#
#  conv_101 (Conv2D)              (None, 52, 52, 128)  32768       ['leaky_100[0][0]']
#
#  bnorm_101 (BatchNormalization)  (None, 52, 52, 128)  512        ['conv_101[0][0]']
#
#  leaky_101 (LeakyReLU)          (None, 52, 52, 128)  0           ['bnorm_101[0][0]']
#
#  conv_102 (Conv2D)              (None, 52, 52, 256)  294912      ['leaky_101[0][0]']
#
#  bnorm_102 (BatchNormalization)  (None, 52, 52, 256)  1024       ['conv_102[0][0]']
#
#  leaky_102 (LeakyReLU)          (None, 52, 52, 256)  0           ['bnorm_102[0][0]']
#
#  conv_103 (Conv2D)              (None, 52, 52, 128)  32768       ['leaky_102[0][0]']
#
#  bnorm_103 (BatchNormalization)  (None, 52, 52, 128)  512        ['conv_103[0][0]']
#
#  leaky_103 (LeakyReLU)          (None, 52, 52, 128)  0           ['bnorm_103[0][0]']
#
#  conv_80 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_79[0][0]']
#                                 )
#
#  conv_92 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_91[0][0]']
#
#  conv_104 (Conv2D)              (None, 52, 52, 256)  294912      ['leaky_103[0][0]']
#
#  bnorm_80 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_80[0][0]']
#                                 )
#
#  bnorm_92 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_92[0][0]']
#
#  bnorm_104 (BatchNormalization)  (None, 52, 52, 256)  1024       ['conv_104[0][0]']
#
#  leaky_80 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_80[0][0]']
#                                 )
#
#  leaky_92 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_92[0][0]']
#
#  leaky_104 (LeakyReLU)          (None, 52, 52, 256)  0           ['bnorm_104[0][0]']
#
#  conv_81 (Conv2D)               (None, 13, 13, 255)  261120      ['leaky_80[0][0]']
#
#  conv_93 (Conv2D)               (None, 26, 26, 255)  130560      ['leaky_92[0][0]']
#
#  conv_105 (Conv2D)              (None, 52, 52, 255)  65280       ['leaky_104[0][0]']
#
#  bnorm_81 (BatchNormalization)  (None, 13, 13, 255)  1020        ['conv_81[0][0]']
#
#  bnorm_93 (BatchNormalization)  (None, 26, 26, 255)  1020        ['conv_93[0][0]']
#
#  bnorm_105 (BatchNormalization)  (None, 52, 52, 255)  1020       ['conv_105[0][0]']
#
#  leaky_81 (LeakyReLU)           (None, 13, 13, 255)  0           ['bnorm_81[0][0]']
#
#  leaky_93 (LeakyReLU)           (None, 26, 26, 255)  0           ['bnorm_93[0][0]']
#
#  leaky_105 (LeakyReLU)          (None, 52, 52, 255)  0           ['bnorm_105[0][0]']
#
# ==================================================================================================
# Total params: 62,053,716
# Trainable params: 61,999,322
# Non-trainable params: 54,394
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True,to_file='./modelo.png')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## 3. Lectura de pesos

# %%
! wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2022-06-26 19:20:00--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  22.9MB/s    in 11s
#
# 2022-06-26 19:20:12 (21.5 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
import struct
import numpy as np

# %%
class ReadWeights:
  def __init__(self, weights_file):
    with open(weights_file, 'rb') as wf:
      major, = struct.unpack('i',wf.read(4))
      minor, = struct.unpack('i',wf.read(4))
      revision, = struct.unpack('i',wf.read(4))
      if (major*10 + minor) >= 2 and major < 1000 and minor <1000:
        print(wf.read(8))
      else:
        print(wf.read(4))
      transpose = (major>1000) or (minor > 1000)
      binary = wf.read()
    self.weights = np.frombuffer(binary, dtype='float32')
    self.offset = 0
  
  def read_weights(self, size):
    weights = self.weights[self.offset:self.offset + size]
    self.offset = self.offset + size
    return weights

  def load_weights(self, model):
    for i in range(106):
      try:
        layer_conv = model.get_layer('conv_'+str(i))
        print("Asignando pesos a la capa",i)
        if i not in [81, 93, 105]:
          layer_bn = model.get_layer('bnorm_'+str(i))
          size = np.prod(layer_bn.get_weights()[0].shape)
          beta = self.read_weights(size)
          gamma = self.read_weights(size)
          mean = self.read_weights(size)
          var = self.read_weights(size)
          layer_bn.set_weights([gamma, beta, mean, var])
        if len(layer_conv.get_weights()) > 1:
          # Tiene bias
          bias_size = np.prod(layer_conv.get_weights()[1].shape)
          bias = self.read_weights(bias_size)
          kernel_size = np.prod(layer_conv.get_weights()[0].shape)
          kernel = self.read_weights(kernel_size)
          kernel = kernel.reshape(list(reversed(layer_conv.get_weights()[0].shape)))
          kernel = kernel.transpose([2,3,1,0])
          layer_conv.set_weights([kernel, bias])
        else:
          kernel_size = np.prod(layer_conv.get_weights()[0].shape)
          kernel = self.read_weights(kernel_size)
          kernel = kernel.reshape(list(reversed(layer_conv.get_weights()[0].shape)))
          kernel = kernel.transpose([2,3,1,0])
          layer_conv.set_weights([kernel])
      except:
        print('Ocurrio un problema')
  def reset(self):
    self.offset = 0

# %%
rw = ReadWeights('/content/yolov3.weights')
# Out:
# b'\x00|\xe8\x01\x00\x00\x00\x00'

# %%
rw.load_weights(model)
# Out:
# Asignando pesos a la capa 0
# Asignando pesos a la capa 1
# Asignando pesos a la capa 2
# Asignando pesos a la capa 3
# Ocurrio un problema
# Asignando pesos a la capa 5
# Asignando pesos a la capa 6
# Asignando pesos a la capa 7
# Ocurrio un problema
# Asignando pesos a la capa 9
# Asignando pesos a la capa 10
# Ocurrio un problema
# Asignando pesos a la capa 12
# Asignando pesos a la capa 13
# Asignando pesos a la capa 14
# Ocurrio un problema
# Asignando pesos a la capa 16
# Asignando pesos a la capa 17
# Ocurrio un problema
# Asignando pesos a la capa 19
# Asignando pesos a la capa 20
# Ocurrio un problema
# Asignando pesos a la capa 22
# Asignando pesos a la capa 23
# Ocurrio un problema
# Asignando pesos a la capa 25
# Asignando pesos a la capa 26
# Ocurrio un problema
# Asignando pesos a la capa 28
# Asignando pesos a la capa 29
# Ocurrio un problema
# Asignando pesos a la capa 31
# Asignando pesos a la capa 32
# Ocurrio un problema
# Asignando pesos a la capa 34
# Asignando pesos a la capa 35
# Ocurrio un problema
# Asignando pesos a la capa 37
# Asignando pesos a la capa 38
# Asignando pesos a la capa 39
# Ocurrio un problema
# Asignando pesos a la capa 41
# Asignando pesos a la capa 42
# Ocurrio un problema
# Asignando pesos a la capa 44
# Asignando pesos a la capa 45
# Ocurrio un problema
# Asignando pesos a la capa 47
# Asignando pesos a la capa 48
# Ocurrio un problema
# Asignando pesos a la capa 50
# Asignando pesos a la capa 51
# Ocurrio un problema
# Asignando pesos a la capa 53
# Asignando pesos a la capa 54
# Ocurrio un problema
# Asignando pesos a la capa 56
# Asignando pesos a la capa 57
# Ocurrio un problema
# Asignando pesos a la capa 59
# Asignando pesos a la capa 60
# Ocurrio un problema
# Asignando pesos a la capa 62
# Asignando pesos a la capa 63
# Asignando pesos a la capa 64
# Ocurrio un problema
# Asignando pesos a la capa 66
# Asignando pesos a la capa 67
# Ocurrio un problema
# Asignando pesos a la capa 69
# Asignando pesos a la capa 70
# Ocurrio un problema
# Asignando pesos a la capa 72
# Asignando pesos a la capa 73
# Ocurrio un problema
# Asignando pesos a la capa 75
# Asignando pesos a la capa 76
# Asignando pesos a la capa 77
# Asignando pesos a la capa 78
# Asignando pesos a la capa 79
# Asignando pesos a la capa 80
# Asignando pesos a la capa 81
# Ocurrio un problema
# Ocurrio un problema
# Asignando pesos a la capa 84
# Ocurrio un problema
# Ocurrio un problema
# Asignando pesos a la capa 87
# Asignando pesos a la capa 88
# Asignando pesos a la capa 89
# Asignando pesos a la capa 90
# Asignando pesos a la capa 91
# Asignando pesos a la capa 92
# Asignando pesos a la capa 93
# Ocurrio un problema
# Ocurrio un problema
# Asignando pesos a la capa 96
# Ocurrio un problema
# Ocurrio un problema
# Asignando pesos a la capa 99
# Asignando pesos a la capa 100
# Asignando pesos a la capa 101
# Asignando pesos a la capa 102
# Asignando pesos a la capa 103
# Asignando pesos a la capa 104
# Asignando pesos a la capa 105

# %% [markdown]
# Guardamos el modelo

# %%
model.save('yolov3.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
! cp /content/yolov3.h5 /content/drive/MyDrive/clases/"Computer Vision Modulo 1"/"Clase 8"/yolov3.h5

# %% [markdown]
# Funciones para extraer los Bounding Box

# %%
def YoloCorrectBoxes(box_xy, box_wh, input_shape, image_shape):
  box_yx = box_xy[..., ::-1]
  box_hw = box_wh[..., ::-1] 
  input_shape = tf.cast(input_shape, tf.dtype(box_yx))
  image_shape = tf.cast(input_shape, tf.dtype(box_yx))
  new_shape = tf.round(image_shape* tf.min(input_shape/image_shape))
  offset = (input_shape - new_shape)/input_shape/2.
  scale = input_shape/new_shape
  box_yx = (box_yx - offset)*scale
  box_hw *= scale

  box_min = box_yx - (box_hw/2.)
  box_max = box_yx + (box_hw/2.)
  # y_min, x_min, y_max, x_max 
  boxes = tf.concatenate([box_min[...,0:1], box_min[...,1:2], box_max[...,0:1], box_max[...,1:2]])
  boxes *= tf.concatenate([image_shape, image_shape])
  return boxes

# %%
def YoloScoreBoxes(feats, anchors, n_class, input_shape, image_shape):
  box_xy, box_wh, box_confidence, box_class = YoloLast(feats, anchors, n_class, input_shape)
  boxes = YoloCorrectBoxes(box_xy, box_wh, input_shape, image_shape)
  boxes = tf.reshape(boxes, [-1,4])
  box_scores = box_confidence * box_class
  box_scores = tf.reshape(box_scores,[-1, n_class])
  return boxes, box_scores
